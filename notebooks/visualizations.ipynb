# %% [markdown]
# ## Visualizations for Data Analysis

# %%
import sys
sys.path.append("..")
import matplotlib.pyplot as plt
from src.movientities.visualizations.mit_viz import MitVisualizations

# %%
MitVisualizations.histogram("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/mitmovies/train.txt", 30)

# %%
MitVisualizations.histogram("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/trivia10k/train.txt", 30)

# %%
MitVisualizations.pie("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/mitmovies")

# %%
MitVisualizations.pie("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/trivia10k")

# %%
MitVisualizations.word_count("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/mitmovies")

# %%
MitVisualizations.word_count("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/trivia10k")

# %%
MitVisualizations.word_frequency("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/mitmovies")

# %%
MitVisualizations.word_frequency("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/trivia10k")

# %%
MitVisualizations.most_frequent("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/mitmovies")

# %%
MitVisualizations.most_frequent("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/trivia10k")

# %%
MitVisualizations.label_counts("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/mitmovies")

# %%
MitVisualizations.label_counts("/home/kemalaraz/Desktop/MovieEntityRecognizer/data/modified/trivia10k")
